# %%
install.packages("lidR", repos = "https://cloud.r-project.org")

# takes a little while to run
# lib = "/databricks/spark/R/lib" will install to cluster so may not need to reinstall each time

# %%
library(tidyverse)
library(lidR)

# %%
getwd()

# %%
path_las = "/Workspace/Users/joseph.beesley@defra.onmicrosoft.com/ReForeSt_LiDAR_data/normalised/"

# %% [markdown]
# Read in a random file to check

# %%
las = readLAS(paste0(path_las, "clip_1105056_2018.las"))

# %%
las

# %%
plot(las)

# pop-out doesn't work

# %%
df_las = payload(las)
names(df_las)

# %%
ggplot(payload(las), aes(X, Y, color = Z)) + 
  geom_point(size = 0.05) + 
  coord_equal() + 
  theme_minimal() +
  scale_color_gradientn(colours = height.colors(50)) +
  theme(legend.position = "none")

# %%
p1 = c(447650, 314700)
p2 = c(447650, 314300)
las_tr = clip_transect(las, p1, p2, width = 5, xz = TRUE)

# %%
ggplot(payload(las_tr), aes(X, Z, color = Z)) + 
  geom_point(size = 0.5) + 
  coord_equal() + 
  theme_classic() +
  scale_color_gradientn(colours = height.colors(50)) +
  theme(legend.position = "none")
