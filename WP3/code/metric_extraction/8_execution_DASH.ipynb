# %% [markdown]
# # DASH execution
#
# Notebook to run the main `7_execution.R` script on the DASH platform by installing necessary packages, assigning the correct working directory and calling the script.

# %% [markdown]
# ### Install packages

# %%
# install older version of Matrix (dependency of lidaRtRee package) that is compatible with R 4.3.1 (version installed on DASH)
install.packages("https://cran.r-project.org/src/contrib/Archive/Matrix/Matrix_1.6-5.tar.gz", repos=NULL, type="source")

# install other required packages
install.packages(c("tidyverse", "tidyterra", "hablar", "sf", "terra", "lidR", "lidaRtRee", "landscapemetrics", "GLCMTextures"))

# %% [markdown]
# ### Run `7_execution.R` script

# %%
setwd("/Workspace/Users/joseph.beesley@defra.onmicrosoft.com/ReForeSt/")

# %%
source("WP3/code/metric_extraction/7_execution.R")
