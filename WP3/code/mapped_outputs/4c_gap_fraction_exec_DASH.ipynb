# %% [markdown]
# # DASH execution - gap fraction
#
# Notebook to run gap fraction scripts on the DASH platform by installing necessary packages, assigning the correct working directory and calling the scripts.

# %% [markdown]
# ### Install packages

# %%
# install other required packages
install.packages(c("tidyverse", "tidyterra", "sf", "terra", "lidaRtRee"))

# %%
setwd("/Workspace/Users/joseph.beesley@defra.onmicrosoft.com/ReForeSt/")
source("WP3/code/mapped_outputs/0_setup_gaps.R")
source("WP3/code/mapped_outputs/1_functions.R")

# %% [markdown]
# ### Run `4a_gap_fraction_DASH.R` script

# %%
source("WP3/code/mapped_outputs/4a_gap_fraction_DASH.R")

# %% [markdown]
# ### Run `4b_gap_fraction_mosaic_DASH.R` script

# %%
source("WP3/code/mapped_outputs/4b_gap_fraction_mosaic_DASH.R")
