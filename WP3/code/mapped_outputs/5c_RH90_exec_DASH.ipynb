# %% [markdown]
# # DASH execution - RH90 map
#
# Notebook to run RH90 scripts on the DASH platform by installing necessary packages, assigning the correct working directory and calling the scripts.

# %% [markdown]
# ### Install packages

# %%
# install required packages
install.packages(c("tidyverse", "tidyterra", "sf", "terra")) #, "lidaRtRee"))

# %%
setwd("/Workspace/Users/joseph.beesley@defra.onmicrosoft.com/ReForeSt/")
source("WP3/code/mapped_outputs/0_setup_gaps.R")
source("WP3/code/mapped_outputs/1_functions.R")

# %% [markdown]
# ### Run `5a_RH90_DASH.R` script

# %%
source("WP3/code/mapped_outputs/5a_RH90_DASH.R")

# %% [markdown]
# ### Run `5b_RH90_mosaic_DASH.R` script

# %%
source("WP3/code/mapped_outputs/5b_RH90_mosaic_DASH.R")
